# %%
import openai

# %%
client = openai.Client()

# %%
assistant = client.beta.assistants(
    name="Tutor de Teologia",
    instructions="Você é um tutor sobre assuntos relacionados a teologia",
    tools=[{"type":"code_interpreter"}],
    model="gpt-3.5-turbo-0125",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 assistant = client.beta.assistants(
#       2     name="Tutor de Teologia",
#       3     instructions="Você é um tutor sobre assuntos relacionados a teologia",
#       4     tools=[{"type":"code_interpreter"}],
#       5     model="gpt-3.5-turbo-0125",
#       6 )
#
# TypeError: 'Assistants' object is not callable

# %% [markdown]
# ### Essa funcionalidade não tem mais no openai
